# %%
import pandas as pd

# %%
data = {'Name':['Alice','Bob'],'Age':[25,30]}

# %%
data
# Out:
# {'Name': ['Alice', 'Bob'], 'Age': [25, 30]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
lst = [['Alice',25],['Bob',30]]

# %%
df=pd.DataFrame(lst,columns=['Name','Age'])

# %%
df
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.head()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.tail()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      str
#  1   Age     2 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 164.0 bytes

# %%
df.describe()
# Out:
#              Age
# count   2.000000
# mean   27.500000
# std     3.535534
# min    25.000000
# 25%    26.250000
# 50%    27.500000
# 75%    28.750000
# max    30.000000

# %%
df['Name']
# Out:
# 0    Alice
# 1      Bob
# Name: Name, dtype: str

# %%
df[['Name','Age']]
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.loc[0]
# Out:
# Name    Alice
# Age        25
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# Name    Bob
# Age      30
# Name: 1, dtype: object

# %%
df[df['Age']>25]
# Out:
#   Name  Age
# 1  Bob   30

# %%
df['Gender']=['F','M']

# %%
df
# Out:
#     Name  Age Gender
# 0  Alice   25      F
# 1    Bob   30      M

# %%
df.drop('Age',axis=1,inplace=True)

# %%
df
# Out:
#     Name Gender
# 0  Alice      F
# 1    Bob      M

# %%
df.isnull()
# Out:
#     Name  Gender
# 0  False   False
# 1  False   False

# %%
df.dropna()
# Out:
#     Name Gender
# 0  Alice      F
# 1    Bob      M

# %%
df.fillna(0)
# Out:
#     Name Gender
# 0  Alice      F
# 1    Bob      M

# %%
df.groupby('Gender')['Age'].mean()
print(df)
# Out:
#     Name  Age Gender
# 0  Alice   25      F
# 1    Bob   30      M

# %%
df1=pd.DataFrame({'key':[1,2],'name':['alice','bob']})
df2=pd.DataFrame({'key':[1,2],'age':[25,30]})

# %%
df1
df2
# Out:
#    key  age
# 0    1   25
# 1    2   30

# %%
pd.merge(df1,df2,on='key')
# Out:
#    key   name  age
# 0    1  alice   25
# 1    2    bob   30

# %%
df
# Out:
#     Name Gender
# 0  Alice      F
# 1    Bob      M

# %%
df1=df1.set_index('key')
df2=df2.set_index('key')

# %%
df1.join(df2)
# Out:
#       name  age
# key
# 1    alice   25
# 2      bob   30

# %%
df1.join(df2)
# Out:
#       name  age
# key
# 1    alice   25
# 2      bob   30

# %%
df
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df
# Out:
#     Name  Age Gender
# 0  Alice   25      F
# 1    Bob   30      M

# %%
df.to_csv('output.csv',index=False)

# %%
df.sort_values('age')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 df.sort_values('age')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:8359, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    8355             )
#    8356         elif by:
#    8357             # len(by) == 1
#    8358
# -> 8359             k = self._get_label_or_level_values(by[0], axis=axis)
#    8360
#    8361             # need to rewrap column in Series to apply key function
#    8362             if key is not None:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:1776, in NDFrame._get_label_or_level_values(self, key, axis)
#    1772             values = self.xs(key, axis=first_other_axes)._values
#    1773         elif self._is_level_reference(key, axis=axis):
#    1774             values = self.axes[axis].get_level_values(key)._values
#    1775         else:
# -> 1776             raise KeyError(key)
#    1777
#    1778         # Check for duplicates
#    1779         if values.ndim > 1:
#
# KeyError: 'age'

# %%
df['Age'].apply(lambda x: x + 1)

# %%
df['Name'].unique()

# %%
df['Age'].value_counts()
